# %% [markdown]
# # Session 9: Functions – Basics – Student Notebook
# **FoP – B.S. in Management and Public Policy**
# Complete the code in the cells below during the 90-min session. Run each cell after filling in.
#
# ---
#
# **References:** Downey, *Think Python*; Matthes, *Python Crash Course* (see course outline).

# %% [markdown]
# ## 1. Define a scheme line function
# Write a function `scheme_line(name, year)` that returns a string like `"<name> (FY <year>)"`. Call it with a scheme name and year and print the result.

# %%
# Your code here
# def scheme_line(name, year):
#     return ...
# print(scheme_line("PM-JAY", 2023))

# %% [markdown]
# ## 2. Function with two parameters
# Write a function `total_alloc(allocated, additional)` that returns the total (e.g. allocated + additional budget in lakhs). Test with (100, 25) and print the result.

# %%
# Your code here
# def total_alloc(allocated, additional):
#     return ...
# print(total_alloc(100, 25))

# %% [markdown]
# ## 3. Function using a list
# Write a function `average_grants(amounts)` that takes a list of grant amounts (in lakhs) and returns their average. If the list is empty, return 0. Test with `[10, 20, 30]`.

# %%
# Your code here
# def average_grants(amounts):
#     if not amounts:
#         return 0
#     return ...
# print(average_grants([10, 20, 30]))

# %% [markdown]
# ## 4. Function using a dictionary
# Write a function `get_scheme(schemes_dict, code)` that takes a dict of scheme code → details and a code, and returns the details if found, otherwise `"Not found"`. Use `.get()`. Test with a dict like `{"AB": "Ayushman Bharat", "PK": "PM-KISAN"}`.

# %%
# Your code here
# def get_scheme(schemes_dict, code):
#     return ...
# schemes = {"AB": "Ayushman Bharat", "PK": "PM-KISAN"}
# print(get_scheme(schemes, "AB"))
# print(get_scheme(schemes, "X"))

# %% [markdown]
# ## 5. Practical task (management/policy) — **In-class 1**
# Write a function `summarize_grants(amounts)` that takes a list of grant amounts (in lakhs) and returns a **dictionary** with keys: `"count"`, `"total"`, and `"average"`. Test with `[50, 75, 100, 25]` (e.g. four districts).

# %%
# Your code here
# def summarize_grants(amounts):
#     ...
#     return {"count": ..., "total": ..., "average": ...}
# print(summarize_grants([50, 75, 100, 25]))

# %% [markdown]
# ---
#
# ## 6. More practice problems
#
# **In-class:** Solve **6.1** and **6.2** during the session (with 5 above = 3 in-class tasks).
# **Homework:** Complete **6.3–6.6** after class. Master notebook has solutions for all.

# %% [markdown]
# ### 6.1 In-class — Format budget in crores
# **Problem:** Write a function `format_cr(amount)` that takes an amount in rupees and returns a string like `"X.X crore"` (e.g. 65000000 → "6.5 crore"). Use amount / 1_00_00_000. Test with 65000000 and 10000000.

# %%
# def format_cr(amount):
#     ...
# print(format_cr(65000000))
# print(format_cr(10000000))

# %% [markdown]
# ### 6.2 In-class — One-line scheme status
# **Problem:** Write a function `scheme_status(s)` that takes a dictionary `s` with keys `"code"`, `"budget_cr"`, and `"ministry"`, and returns one string: `"<code>: <budget_cr> cr (<ministry>)"`. Example: `scheme_status({"code": "AB", "budget_cr": 6500, "ministry": "Health"})` → `"AB: 6500 cr (Health)"`.

# %%
# def scheme_status(s):
#     return ...
# print(scheme_status({"code": "AB", "budget_cr": 6500, "ministry": "Health"}))

# %% [markdown]
# ### 6.3 Homework — Count above threshold
# **Problem:** Write a function `count_above(amounts, threshold)` that returns how many values in the list `amounts` are >= `threshold`. E.g. `count_above([50, 75, 30, 80], 50)` → 3. Useful for "how many districts got at least X lakh?"

# %%
# def count_above(amounts, threshold):
#     ...
# print(count_above([50, 75, 30, 80], 50))

# %% [markdown]
# ### 6.4 Homework — Indicator lookup
# **Problem:** Write a function `lookup_indicator(indicators, code)` that takes a dict `indicators` (code → indicator name) and a `code`, and returns the indicator name or `"Not found"`. Use `.get()`. Test with `{"ENR": "Enrollment rate", "LIT": "Literacy"}` and code "ENR" then "XYZ".

# %%
# def lookup_indicator(indicators, code):
#     return ...
# ind = {"ENR": "Enrollment rate", "LIT": "Literacy"}
# print(lookup_indicator(ind, "ENR"))
# print(lookup_indicator(ind, "XYZ"))

# %% [markdown]
# ### 6.5 Homework — Report line
# **Problem:** Write a function `report_line(scheme_name, amount_lakhs)` that returns a single string: `"Scheme: <name> | Amount: <amount> lakh"`. E.g. `report_line("PM-JAY", 100)` → `"Scheme: PM-JAY | Amount: 100 lakh"`.

# %%
# def report_line(scheme_name, amount_lakhs):
#     return ...
# print(report_line("PM-JAY", 100))

# %% [markdown]
# ### 6.6 Homework — Merge totals (two dicts)
# **Problem:** Write a function `merge_totals(d1, d2)` that takes two dictionaries (scheme code → amount in lakhs) and returns a **new** dict with all keys from both; for keys in both, add the amounts. E.g. `merge_totals({"AB": 100, "PK": 50}, {"AB": 25, "PK": 75})` → `{"AB": 125, "PK": 125}`.

# %%
# def merge_totals(d1, d2):
#     ...
# print(merge_totals({"AB": 100, "PK": 50}, {"AB": 25, "PK": 75}))
