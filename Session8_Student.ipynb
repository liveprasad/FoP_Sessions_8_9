# %% [markdown]
# # Session 8: Tuples, Sets & Dictionaries – Student Notebook
# **FoP – B.S. in Management and Public Policy**
# Complete the code in the cells below during the 90-min session. Run each cell after filling in.
#
# ---
#
# **References:** Downey, *Think Python*; Matthes, *Python Crash Course* (see course outline).

# %% [markdown]
# ## 1. Tuples
# Create a tuple `scheme_record` with three elements: a scheme name (string), year (int), and budget in lakhs (int). Print the first and third element (name and budget).

# %%
# Your code here (e.g. a policy/scheme record)
scheme_record =  # ("Scheme Name", year, budget_lakhs)
print()
print()

# %% [markdown]
# Unpack `scheme_record` into three variables `name`, `yr`, and `budget` and print them.

# %%
# Your code here
# name, yr, budget = ...
# print(...)

# %% [markdown]
# ## 2. Sets
# Given the list `dept_codes = ["HEALTH", "EDU", "HEALTH", "RURAL", "EDU", "HEALTH"]` (departments that submitted reports), create a set of unique codes and print the number of unique departments.

# %%
dept_codes = ["HEALTH", "EDU", "HEALTH", "RURAL", "EDU", "HEALTH"]
# unique_depts = ...
# print("Number of unique departments:", ...)

# %% [markdown]
# ## 3. Dictionaries
# Create a dictionary `scheme` with keys: `"code"`, `"name"`, `"year"`, and `"budget_cr"` (budget in crores). Assign values for a public policy/scheme you know. Print the value for `"name"`.

# %%
# Your code here (e.g. one scheme/policy)
# scheme = { "code": "...", "name": "...", "year": ..., "budget_cr": ... }
# print(...)

# %% [markdown]
# Loop over `scheme.items()` and print each key and value.

# %%
# Your code here
# for key, value in scheme.items():
#     print(...)

# %% [markdown]
# ## 4. Practical task (policy/stakeholder context) — **In-class 1**
# Given `feedback = ["Support", "Oppose", "Support", "Support", "Oppose"]` (stakeholder feedback on a policy), find the **unique** responses and print them. Then create a dict `label = {"Support": "In favour", "Oppose": "Against"}` and for each unique response print its label.

# %%
feedback = ["Support", "Oppose", "Support", "Support", "Oppose"]
# unique_feedback = ...
# label = {"Support": "In favour", "Oppose": "Against"}
# for r in unique_feedback:
#     print(...)

# %% [markdown]
# ---
#
# ## 5. More practice problems
#
# **In-class:** Solve **5.1** and **5.2** during the 90-min session (with 4 above = 3 in-class tasks).
# **Homework:** Complete **5.3–5.7** after class. **5.7** is a challenge problem (tuples + sets + dicts). Master notebook has solutions for all.

# %% [markdown]
# ### 5.1 In-class — KPI record (tuple)
# **Problem:** Store a single KPI record as a tuple: `(indicator_name, target_value, achieved_value)`. Example: `("Enrollment rate (%)", 95, 88)`. Unpack into three variables and compute achievement percentage (achieved / target * 100). Print the indicator name and achievement %.

# %%
# Your code here
# kpi = ("Enrollment rate (%)", 95, 88)
# name, target, achieved = ...
# pct = ...
# print(...)

# %% [markdown]
# ### 5.2 In-class — Unique scheme codes (set)
# **Problem:** The list `scheme_codes = ["AB", "PK", "AB", "MS", "PK", "AB"]` shows which schemes received grants (duplicates = multiple releases). Find the **unique** scheme codes and print how many unique schemes there are.

# %%
scheme_codes = ["AB", "PK", "AB", "MS", "PK", "AB"]
# unique_schemes = ...
# print("Number of unique schemes:", ...)

# %% [markdown]
# ### 5.3 Homework — District code to name (dictionary)
# **Problem:** Create a dictionary `districts` mapping code → name: e.g. `{"D1": "Bargarh", "D2": "Sambalpur", "D3": "Sundargarh"}`. Given `codes = ["D1", "D3", "D2", "D4"]`, loop and print the district name for each code. Use `.get(code, "Unknown")` so missing codes (e.g. D4) print "Unknown".

# %%
# districts = {"D1": "Bargarh", "D2": "Sambalpur", "D3": "Sundargarh"}
# codes = ["D1", "D3", "D2", "D4"]
# for code in codes:
#     print(...)

# %% [markdown]
# ### 5.4 Homework — Total amount per scheme (dict + list)
# **Problem:** You have releases as a list of tuples: `releases = [("AB", 100), ("PK", 50), ("AB", 75), ("PK", 25)]` (scheme code, amount in lakhs). Build a dictionary that, for each scheme code, holds the **total** amount. Print the dict. (Hint: loop over releases and add amount to dict[code].)

# %%
# releases = [("AB", 100), ("PK", 50), ("AB", 75), ("PK", 25)]
# totals = {}  # or dict()
# for code, amount in releases:
#     ...
# print(totals)

# %% [markdown]
# ### 5.5 Homework — Satisfaction survey (set + dict)
# **Problem:** Survey responses: `responses = ["Satisfied", "Neutral", "Satisfied", "Unsatisfied", "Neutral"]`. Find **unique** responses. Create a dict `label = {"Satisfied": "Positive", "Neutral": "Neutral", "Unsatisfied": "Negative"}`. For each unique response, print the response and its label.

# %%
# responses = ["Satisfied", "Neutral", "Satisfied", "Unsatisfied", "Neutral"]
# unique_resp = ...
# label = {"Satisfied": "Positive", "Neutral": "Neutral", "Unsatisfied": "Negative"}
# for r in unique_resp:
#     print(...)

# %% [markdown]
# ### 5.6 Homework — Policy milestones (tuples in list)
# **Problem:** Store three policy milestones as tuples: `(name, quarter, status)`. E.g. `("Phase 1 rollout", "Q2", "Completed")`, `("Phase 2", "Q3", "Due")`, `("Review", "Q4", "Pending")`. Put them in a list. Loop and print only those with status **"Due"** or **"Completed"**.

# %%
# milestones = [
#     ("Phase 1 rollout", "Q2", "Completed"),
#     ("Phase 2", "Q3", "Due"),
#     ("Review", "Q4", "Pending")
# ]
# for name, quarter, status in milestones:
#     if status in ("Due", "Completed"):
#         print(...)

# %% [markdown]
# ### 5.7 Homework — **Challenge** (tuples + sets + dicts)
# **Problem:** You have a list of **releases**: each item is a tuple `(scheme_code, district_code, amount_lakhs)` — a grant release to a district under a scheme. Example:
#
# `releases = [("AB", "D1", 50), ("PK", "D1", 30), ("AB", "D2", 75), ("MS", "D1", 20), ("PK", "D2", 40)]`
#
# **Do the following (use tuples, sets, and dicts):**
# 1. Find the **set of unique scheme codes** and the **set of unique district codes**.
# 2. Build **totals_by_scheme**: a dict mapping each scheme code to the **total** amount released (sum over all districts).
# 3. Build **totals_by_district**: a dict mapping each district code to the **total** amount received (sum over all schemes).
# 4. Find and print which **districts received releases from more than one scheme** (e.g. D1 got AB, PK, MS).
# 5. Print the **scheme with the maximum total release** and that total.
#
# This combines unpacking tuples, sets for uniqueness, and dicts for aggregation — try without peeking at the solution.

# %%
# releases = [("AB", "D1", 50), ("PK", "D1", 30), ("AB", "D2", 75), ("MS", "D1", 20), ("PK", "D2", 40)]
# 1. unique schemes, unique districts (sets)
# 2. totals_by_scheme[code] = sum of amount for that scheme
# 3. totals_by_district[district] = sum of amount for that district
# 4. districts with >1 scheme (hint: dict district -> set of schemes)
# 5. scheme with max total (max on totals_by_scheme)
